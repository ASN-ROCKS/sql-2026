-- %%
SELECT 'Olá mundo!'

-- %%
SELECT 1+1 AS um_mais_um

-- %%
SELECT weekday('1961-07-18')

-- %%
SELECT *                           -- TODAS AS COLUNAS
FROM workspace.tmw_points.clientes -- catalogo.database.tabela
LIMIT 10                           -- LIMITA QUANTIDADE DE LINHAS

-- %%
SELECT 
       idCliente,
       qtdePontos,
       DtCriacao,
       DtAtualizacao

FROM workspace.tmw_points.clientes -- catalogo.database.tabela
LIMIT 1                            -- LIMITA QUANTIDADE DE LINHAS

-- %%
-- 1 + 1 = 2   |   VERDADE OU VERDADE = VERDADE
-- 1 + 0 = 1   |   VERDADE OU FALSO   = VERDADE
-- 0 + 1 = 1   |   FALSO   OU VERDADE = VERDADE
-- 0 + 0 = 0   |   FALSE   OU FALSO   = FALSO

-- 1 * 1 = 1   |   VERDADE E VERDADE = VERDADE
-- 1 * 0 = 0   |   VERDADE E FALSO   = FALSO
-- 0 * 1 = 0   |   FALSO   E VERDADE = FALSO
-- 0 * 0 = 0   |   FALSE   E FALSO   = FALSO

-- %%
-- usuários com mais de 1000 pontos
SELECT *
FROM workspace.tmw_points.clientes
WHERE qtdePontos > 1000
