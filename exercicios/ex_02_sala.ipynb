-- %%
-- Quantos clientes tem Twitch?

-- SELECT count(*) -- 3331
-- FROM workspace.tmw_points.clientes
-- WHERE flTwitch = 1

-- SELECT sum(flTwitch), -- 3331
--        AVG(flTwitch)
-- FROM workspace.tmw_points.clientes
